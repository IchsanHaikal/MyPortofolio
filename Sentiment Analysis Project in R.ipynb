# %% [markdown]
# # Developing our Sentiment Analysis Model in R

# %% [markdown]
# We will carry out sentiment analysis with R in this project. The dataset that we will use will be provided by the R package ‘janeaustenR’.
#
# In order to build our project on sentiment analysis, we will make use of the tidytext package that comprises of sentiment lexicons that are present in the dataset of ‘sentiments’.

# %%
library(tidytext)
sentiments
# Out:
#       word               sentiment   lexicon  score
# 1     abacus             trust       nrc      NA
# 2     abandon            fear        nrc      NA
# 3     abandon            negative    nrc      NA
# 4     abandon            sadness     nrc      NA
# 5     abandoned          anger       nrc      NA
# 6     abandoned          fear        nrc      NA
# 7     abandoned          negative    nrc      NA
# 8     abandoned          sadness     nrc      NA
# 9     abandonment        anger       nrc      NA
# 10    abandonment        fear        nrc      NA
# 11    abandonment        negative    nrc      NA
# 12    abandonment        sadness     nrc      NA
# 13    abandonment        surprise    nrc      NA
# 14    abba               positive    nrc      NA
# 15    abbot              trust       nrc      NA
# 16    abduction          fear        nrc      NA
# 17    abduction          negative    nrc      NA
# 18    abduction          sadness     nrc      NA
# 19    abduction          surprise    nrc      NA
# 20    aberrant           negative    nrc      NA
# 21    aberration         disgust     nrc      NA
# 22    aberration         negative    nrc      NA
# 23    abhor              anger       nrc      NA
# 24    abhor              disgust     nrc      NA
# 25    abhor              fear        nrc      NA
# 26    abhor              negative    nrc      NA
# 27    abhorrent          anger       nrc      NA
# 28    abhorrent          disgust     nrc      NA
# 29    abhorrent          fear        nrc      NA
# 30    abhorrent          negative    nrc      NA
# ...   ...                ...         ...      ...
# 27285 efficacy           superfluous loughran NA
# 27286 exigent            superfluous loughran NA
# 27287 expeditiously      superfluous loughran NA
# 27288 extant             superfluous loughran NA
# 27289 furthermore        superfluous loughran NA
# 27290 germane            superfluous loughran NA
# 27291 howsoever          superfluous loughran NA
# 27292 impost             superfluous loughran NA
# 27293 imposts            superfluous loughran NA
# 27294 imputation         superfluous loughran NA
# 27295 imputed            superfluous loughran NA
# 27296 investigatory      superfluous loughran NA
# 27297 mandatorily        superfluous loughran NA
# 27298 nonetheless        superfluous loughran NA
# 27299 obviate            superfluous loughran NA
# 27300 plenary            superfluous loughran NA
# 27301 preponderance      superfluous loughran NA
# 27302 presumptive        superfluous loughran NA
# 27303 propagation        superfluous loughran NA
# 27304 proscribe          superfluous loughran NA
# 27305 putative           superfluous loughran NA
# 27306 recharacterization superfluous loughran NA
# 27307 redetermination    superfluous loughran NA
# 27308 redetermined       superfluous loughran NA
# 27309 stratum            superfluous loughran NA
# 27310 superannuation     superfluous loughran NA
# 27311 theses             superfluous loughran NA
# 27312 ubiquitous         superfluous loughran NA
# 27313 wheresoever        superfluous loughran NA
# 27314 whilst             superfluous loughran NA

# %% [markdown]
# We will make use of three general purpose lexicons like
#
# AFINN |
# bing |
# loughran
#
# These three lexicons make use of the unigrams. Unigrams are a type of n-gram model that consists of a sequence of 1 item, that is, a word collected from a given textual data. In the AFINN lexicon model scores the words in a range from -5 to 5. The increase in negativity corresponds the negative sentiment whereas an increase in positivity corresponds the positive one. The bing lexicon model on the other hand, classifies the sentiment into a binary category of negative or positive. And finally, the loughran model that performs analysis of the shareholder’s reports. In this project, we will make use of the bing lexicons to extract the sentiments out of our data. We can retrieve these lexicons using the get_sentiments() function. We can implement this as follows

# %%
get_sentiments("bing")
# Out:
#      word          sentiment
# 1    2-faced       negative
# 2    2-faces       negative
# 3    a+            positive
# 4    abnormal      negative
# 5    abolish       negative
# 6    abominable    negative
# 7    abominably    negative
# 8    abominate     negative
# 9    abomination   negative
# 10   abort         negative
# 11   aborted       negative
# 12   aborts        negative
# 13   abound        positive
# 14   abounds       positive
# 15   abrade        negative
# 16   abrasive      negative
# 17   abrupt        negative
# 18   abruptly      negative
# 19   abscond       negative
# 20   absence       negative
# 21   absent-minded negative
# 22   absentee      negative
# 23   absurd        negative
# 24   absurdity     negative
# 25   absurdly      negative
# 26   absurdness    negative
# 27   abundance     positive
# 28   abundant      positive
# 29   abuse         negative
# 30   abused        negative
# ...  ...           ...
# 6759 wrestle       negative
# 6760 wretch        negative
# 6761 wretched      negative
# 6762 wretchedly    negative
# 6763 wretchedness  negative
# 6764 wrinkle       negative
# 6765 wrinkled      negative
# 6766 wrinkles      negative
# 6767 wrip          negative
# 6768 wripped       negative
# 6769 wripping      negative
# 6770 writhe        negative
# 6771 wrong         negative
# 6772 wrongful      negative
# 6773 wrongly       negative
# 6774 wrought       negative
# 6775 yawn          negative
# 6776 yay           positive
# 6777 youthful      positive
# 6778 zap           negative
# 6779 zapped        negative
# 6780 zaps          negative
# 6781 zeal          positive
# 6782 zealot        negative
# 6783 zealous       negative
# 6784 zealously     negative
# 6785 zenith        positive
# 6786 zest          positive
# 6787 zippy         positive
# 6788 zombie        negative

# %% [markdown]
# # Performing Sentiment Analysis with the Inner Join

# %% [markdown]
# In this step, we will import our libraries ‘janeaustenr’, ‘stringr’ as well as ‘tidytext’. The janeaustenr package will provide us with the textual data in the form of books authored by the novelist Jane Austen. Tidytext will allow us to perform efficient text analysis on our data. We will convert the text of our books into a tidy format using unnest_tokens() function.

# %%
library(janeaustenr)
library(stringr)
library(tidytext)
library(dplyr)

tidy_data <- austen_books() %>%
 group_by(book) %>%
 mutate(linenumber = row_number(),
   chapter = cumsum(str_detect(text, regex("^chapter [\\divxlc]", 
                          ignore_case = TRUE)))) %>%
ungroup() %>%
unnest_tokens(word, text)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# We have performed the tidy operation on our text such that each row contains a single word. We will now make use of the “bing” lexicon to and implement filter() over the words that correspond to joy. We will use the book Sense and Sensibility and derive its words to implement out sentiment analysis model.

# %%
positive_senti <- get_sentiments("bing") %>%
 filter(sentiment == "positive")

tidy_data %>%
 filter(book == "Emma") %>%
 semi_join(positive_senti) %>%
 count(word, sort = TRUE)
# Out:
# Joining, by = "word"
#     word           n
# 1   well           401
# 2   good           359
# 3   great          264
# 4   like           200
# 5   better         173
# 6   enough         129
# 7   happy          125
# 8   love           117
# 9   pleasure       115
# 10  right           92
# 11  best            85
# 12  happiness       76
# 13  pretty          68
# 14  perfectly       67
# 15  ready           66
# 16  comfort         65
# 17  assure          59
# 18  superior        59
# 19  satisfied       52
# 20  affection       50
# 21  agreeable       50
# 22  glad            50
# 23  wonder          49
# 24  pleased         47
# 25  smile           44
# 26  strong          44
# 27  regard          43
# 28  respect         43
# 29  fine            42
# 30  proper          42
# ... ...            ...
# 639 spontaneous    1
# 640 steadiest      1
# 641 stimulate      1
# 642 stimulative    1
# 643 strikingly     1
# 644 sublime        1
# 645 suffice        1
# 646 sweeping       1
# 647 tempting       1
# 648 tenderly       1
# 649 thinner        1
# 650 thoughtfully   1
# 651 thrive         1
# 652 thriving       1
# 653 tidy           1
# 654 triumphant     1
# 655 triumphantly   1
# 656 unbiased       1
# 657 undaunted      1
# 658 unequivocal    1
# 659 unequivocally  1
# 660 unquestionably 1
# 661 unselfish      1
# 662 useable        1
# 663 vouch          1
# 664 win            1
# 665 winning        1
# 666 wins           1
# 667 wisely         1
# 668 works          1

# %% [markdown]
# From our above result, we observe many positive words like “good”, “happy”, “love” etc. In the next step, we will use spread() function to segregate our data into separate columns of positive and negative sentiments. We will then use the mutate() function to calculate the total sentiment, that is, the difference between positive and negative sentiment.

# %%
library(tidyr)
bing <- get_sentiments("bing")
Emma_sentiment <- tidy_data %>%
 inner_join(bing) %>%
 count(book = "Emma" , index = linenumber %/% 80, sentiment) %>%
 spread(sentiment, n, fill = 0) %>%
 mutate(sentiment = positive - negative)
# Out:
# Joining, by = "word"

# %% [markdown]
# In the next step, we will visualize the words present in the book “Emma” based on their corrosponding positive and negative scores.

# %%
library(ggplot2)
ggplot(Emma_sentiment, aes(index, sentiment, fill = book)) +
 geom_bar(stat= "identity", show.legend = TRUE) +
 facet_wrap(~book, ncol = 2, scales = "free_x")
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# plot without title

# %% [markdown]
# Let us now proceed towards counting the most common positive and negative words that are present in the novel.

# %%
counting_words <- tidy_data %>%
 inner_join(bing) %>%
 count(word, sentiment, sort = TRUE)
head(counting_words)
# Out:
# Joining, by = "word"
#   word   sentiment n
# 1 miss   negative  1855
# 2 well   positive  1523
# 3 good   positive  1380
# 4 great  positive   981
# 5 like   positive   725
# 6 better positive   639

# %% [markdown]
# In the next step, we will perform visualization of our sentiment score. We will plot the scores along the axis that is labeled with both positive as well as negative words. We will use ggplot() function to visualize our data based on their scores.

# %%
counting_words %>%
 filter(n > 150) %>%
 mutate(n = ifelse(sentiment == "negative", -n, n)) %>%
 mutate(word = reorder(word, n)) %>%
 ggplot(aes(word, n, fill = sentiment))+
 geom_col() +
 coord_flip() +
 labs(y = "Sentiment Score")
# Out:
# plot without title

# %% [markdown]
# In the final visualization, let us create a wordcloud that will delineate the most recurring positive and negative words. In particular, we will use the comparision.cloud() function to plot both negative and positive words in a single wordcloud as follows:

# %%
library(reshape2)
library(wordcloud)
tidy_data %>%
 inner_join(bing) %>%
 count(word, sentiment, sort = TRUE) %>%
 acast(word ~ sentiment, value.var = "n", fill = 0) %>%
 comparison.cloud(colors = c("red", "dark green"),
                  max.words = 100)
# Out:
# Loading required package: RColorBrewer
# Joining, by = "word"
# plot without title

# %% [markdown]
# This word cloud will enable us to efficiently visualize the negative as well as positive groups of data. Therefore, we are now able to see the different groups of data based on their corresponding sentiments.
